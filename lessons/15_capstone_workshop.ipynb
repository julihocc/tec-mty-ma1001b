# %% [markdown]
# # Capstone Workshop: Real Data, Model Justification, And Communication
#
# Official MA1001B alignment: 7.5-7.6 blocks, Latin squares, Graeco-Latin squares, factorial designs, and challenge outcomes.
#
# Dataset path: `data/raw/capstone/`

# %% [markdown]
# ## Learning Objectives
#
# - Connect a real decision question to the right statistical evidence.
# - Prepare reproducible capstone notebooks.
# - Draft a recommendation with assumptions and limitations.

# %% [markdown]
# ## Data Context
#
# Student-selected Kaggle or approved public dataset.
#
# If the expected real dataset is missing, this notebook uses a small simulated
# dataset so the statistical workflow remains runnable. Replace the simulated
# data with the real dataset before submitting graded work.

# %%
import pandas as pd

capstone_checklist = pd.DataFrame({
    "section": [
        "decision question",
        "data source citation",
        "exploratory analysis",
        "uncertainty quantification",
        "test or model comparison",
        "assumptions",
        "limitations and ethics",
        "recommendation",
    ],
    "complete": [False] * 8,
})

capstone_checklist

# %% [markdown]
# ## Guided Practice

# %%
capstone_risks = pd.DataFrame({
    "risk": ["missing data", "sampling bias", "weak practical effect", "assumption violation"],
    "mitigation": [
        "document cleaning and sensitivity checks",
        "describe population limits",
        "report effect size and uncertainty",
        "choose robust method or qualify conclusion",
    ],
})
capstone_risks

# %% [markdown]
# ## Decision Interpretation
#
# What is the one decision your capstone will support, and what evidence would make you change your recommendation?
#
# Write 4-6 sentences that separate the estimate or test result from the decision
# recommendation. Include one limitation.

# %% [markdown]
# ## Independent Practice
#
# 1. Modify one assumption in the analysis.
# 2. Re-run the notebook from top to bottom.
# 3. Explain whether the recommendation changed.
